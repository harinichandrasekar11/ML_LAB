# %%
import boto3
import sagemaker
import pandas as pd
import numpy as np

print("All packages imported successfully")
# Out:
# All packages imported successfully

# %%
import sagemaker

session = sagemaker.Session()

print("SageMaker session created successfully")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 import sagemaker
# ----> 3 session = sagemaker.Session()
#       5 print("SageMaker session created successfully")
#
# AttributeError: module 'sagemaker' has no attribute 'Session'

# %%
import boto3
import sagemaker
import pandas as pd
import numpy as np

print("Boto3 version:", boto3.__version__)
print("SageMaker package imported successfully")
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Boto3 version: 1.43.93
# SageMaker package imported successfully
# Pandas version: 2.3.3
# NumPy version: 2.3.5

# %%
import sagemaker 
import boto3 
import pandas as pd 
import numpy as np 
print("Libraries imported successfully")
# Out:
# Libraries imported successfully
